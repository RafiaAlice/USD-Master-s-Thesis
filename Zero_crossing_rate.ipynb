# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pickle

# %%
infile = open('./csDataframe.pkl', 'rb')
data = pickle.load(infile)
infile.close()
for row in data.itertuples():
    x, sr = row.npArr , 4000
    def make_image(data, outputname, size=(1, 1), dpi=80):
        
        fig = plt.figure()
        ax = plt.Axes(fig, [0., 0., 1., 1.])
        ax.set_axis_off()
        fig.add_axes(ax)
        plt.set_cmap('hot')

        time2 = np.linspace(
            0, # start
            len(x)/sr,
            num = len(data)
        )
        n0 = 9000
        n1 = 9100
        plt.plot(x[n0:n1])
        librosa.display.waveplot(x,color='skyblue', sr=sr)
        plt.savefig(f'./zero_crossing_rate/Segment of {row.File_Name} at {row.Start} to {row.End}.png', dpi=250)
        plt.clf()
    
    data = np.arange(1,10).reshape((3, 3))

    make_image(x, f'./zero_crossing_rate/Segment of {row.File_Name} at {row.Start} to {row.End}.png', dpi=250)
# Out:
# C:\Users\RAFIA~1.ALI\AppData\Local\Temp/ipykernel_5196/1158935416.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
