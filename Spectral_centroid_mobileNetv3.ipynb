# %% [markdown]
# # Spectral_centroid_mobileNetv3

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras import optimizers, losses, activations, models
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import tensorflow as tf
from tensorflow.keras.layers import Input, DepthwiseConv2D
from tensorflow.keras.layers import Conv2D, BatchNormalization
from tensorflow.keras.layers import ReLU, AvgPool2D, Flatten, Dense
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import MobileNet
from keras.layers import Dense
from keras import Model
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
train_path= 'C:/Users/ASUS/Desktop/res_spectral_centroid/train'
test_path= 'C:/Users/ASUS/Desktop/res_spectral_centroid/test'
class_names=os.listdir(train_path)
class_names_test=os.listdir(test_path)

# %%
print(class_names)
print(class_names_test)
# Out:
# ['abnormal', 'normal']
# ['abnormal', 'normal']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15)
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory('C:/Users/ASUS/Desktop/res_spectral_centroid/train',target_size=(224, 224),batch_size=32,shuffle=True,class_mode='binary')
test_generator = test_datagen.flow_from_directory('C:/Users/ASUS/Desktop/res_spectral_centroid/test',target_size=(224,224),batch_size=32,shuffle=False,class_mode='binary')
# Out:
# Found 495 images belonging to 2 classes.
# Found 211 images belonging to 2 classes.

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

mobilenet = MobileNetV2(weights = "imagenet",include_top = False,input_shape=(224,224,3))
for layer in mobilenet.layers:
    layer.trainable = False
    
    
model = Sequential()
model.add(mobilenet)
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dense(128,activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(128,activation='relu'))
model.add(Flatten())
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  flatten_2 (Flatten)         (None, 62720)             0
#
#  dense_5 (Dense)             (None, 1)                 62721
#
# =================================================================
# Total params: 2,320,705
# Trainable params: 62,721
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# weight_path="{}_weights.best.hdf5".format('spectro_sound_model')
checkpoint = ModelCheckpoint(filepath ="./check.hDf5", monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)
# reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', 
#                                    factor=0.8, patience=5, 
#                                    verbose=1, mode='auto', 
#                                    epsilon=0.0001, cooldown=5, 
#                                    min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early]

# %%
import tensorflow as tf
from keras.models import *
from keras.layers import *
opt = tf.optimizers.Adam(lr=1e-3)
model.compile(optimizer=opt, 
    loss=losses.binary_crossentropy, 
    metrics=['accuracy', 'Precision', 'AUC', tf.keras.metrics.Recall(), tf.keras.metrics.TrueNegatives()])

# %%
training_images = 456
validation_images = 144 

history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results. 
                   epochs = 50,  # change this for better results
                   validation_data = test_generator)  # this should be equal to total number of images in validation set.
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_23460/615836474.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results.
# Epoch 1/50
# 16/16 [==============================] - 60s 3s/step - loss: 2.4976 - accuracy: 0.5899 - precision: 0.6014 - auc: 0.6059 - recall_2: 0.6500 - true_negatives_2: 123.0000 - val_loss: 3.8337 - val_accuracy: 0.5592 - val_precision: 0.5515 - val_auc: 0.5756 - val_recall_2: 0.9469 - val_true_negatives_2: 11.0000
# Epoch 2/50
# 16/16 [==============================] - 46s 3s/step - loss: 1.2659 - accuracy: 0.6465 - precision: 0.6592 - auc: 0.6908 - recall_2: 0.6769 - true_negatives_2: 144.0000 - val_loss: 1.9755 - val_accuracy: 0.5640 - val_precision: 0.5512 - val_auc: 0.6401 - val_recall_2: 1.0000 - val_true_negatives_2: 6.0000
# Epoch 3/50
# 16/16 [==============================] - 49s 3s/step - loss: 1.0323 - accuracy: 0.6566 - precision: 0.6875 - auc: 0.7110 - recall_2: 0.6346 - true_negatives_2: 160.0000 - val_loss: 1.1979 - val_accuracy: 0.6493 - val_precision: 0.6345 - val_auc: 0.6243 - val_recall_2: 0.8142 - val_true_negatives_2: 45.0000
# Epoch 4/50
# 16/16 [==============================] - 46s 3s/step - loss: 0.9479 - accuracy: 0.6525 - precision: 0.6606 - auc: 0.7133 - recall_2: 0.6962 - true_negatives_2: 142.0000 - val_loss: 1.1679 - val_accuracy: 0.6351 - val_precision: 0.6385 - val_auc: 0.6161 - val_recall_2: 0.7345 - val_true_negatives_2: 51.0000
# Epoch 5/50
# 16/16 [==============================] - 45s 3s/step - loss: 0.9732 - accuracy: 0.6768 - precision: 0.7083 - auc: 0.7221 - recall_2: 0.6538 - true_negatives_2: 165.0000 - val_loss: 2.0578 - val_accuracy: 0.6161 - val_precision: 0.5860 - val_auc: 0.6392 - val_recall_2: 0.9646 - val_true_negatives_2: 21.0000
# Epoch 6/50
# 16/16 [==============================] - 45s 3s/step - loss: 1.0128 - accuracy: 0.6747 - precision: 0.6882 - auc: 0.7226 - recall_2: 0.6962 - true_negatives_2: 153.0000 - val_loss: 1.1436 - val_accuracy: 0.6682 - val_precision: 0.6463 - val_auc: 0.6904 - val_recall_2: 0.8407 - val_true_negatives_2: 46.0000
# Epoch 7/50
# 16/16 [==============================] - 45s 3s/step - loss: 1.0511 - accuracy: 0.6525 - precision: 0.6679 - auc: 0.7232 - recall_2: 0.6731 - true_negatives_2: 148.0000 - val_loss: 2.1270 - val_accuracy: 0.5640 - val_precision: 0.5538 - val_auc: 0.6605 - val_recall_2: 0.9558 - val_true_negatives_2: 11.0000
# Epoch 8/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.8576 - accuracy: 0.6646 - precision: 0.6822 - auc: 0.7314 - recall_2: 0.6769 - true_negatives_2: 153.0000 - val_loss: 1.0760 - val_accuracy: 0.6351 - val_precision: 0.6731 - val_auc: 0.6720 - val_recall_2: 0.6195 - val_true_negatives_2: 64.0000
# Epoch 9/50
# 16/16 [==============================] - 44s 3s/step - loss: 0.8739 - accuracy: 0.6869 - precision: 0.6923 - auc: 0.7618 - recall_2: 0.7269 - true_negatives_2: 151.0000 - val_loss: 1.1098 - val_accuracy: 0.5782 - val_precision: 0.6277 - val_auc: 0.6423 - val_recall_2: 0.5221 - val_true_negatives_2: 63.0000
# Epoch 10/50
# 16/16 [==============================] - 46s 3s/step - loss: 0.7179 - accuracy: 0.7232 - precision: 0.7375 - auc: 0.7878 - recall_2: 0.7346 - true_negatives_2: 167.0000 - val_loss: 1.4128 - val_accuracy: 0.5355 - val_precision: 0.6271 - val_auc: 0.6262 - val_recall_2: 0.3274 - val_true_negatives_2: 76.0000
# Epoch 11/50
# 16/16 [==============================] - 46s 3s/step - loss: 1.2883 - accuracy: 0.6626 - precision: 0.6755 - auc: 0.7240 - recall_2: 0.6885 - true_negatives_2: 149.0000 - val_loss: 1.5644 - val_accuracy: 0.6398 - val_precision: 0.6457 - val_auc: 0.6372 - val_recall_2: 0.7257 - val_true_negatives_2: 53.0000
# Epoch 12/50
# 16/16 [==============================] - 44s 3s/step - loss: 1.3221 - accuracy: 0.6343 - precision: 0.6599 - auc: 0.7039 - recall_2: 0.6269 - true_negatives_2: 151.0000 - val_loss: 1.7649 - val_accuracy: 0.6445 - val_precision: 0.6301 - val_auc: 0.6170 - val_recall_2: 0.8142 - val_true_negatives_2: 44.0000
# Epoch 13/50
# 16/16 [==============================] - 43s 3s/step - loss: 1.2923 - accuracy: 0.6586 - precision: 0.6770 - auc: 0.7283 - recall_2: 0.6692 - true_negatives_2: 152.0000 - val_loss: 2.5810 - val_accuracy: 0.6019 - val_precision: 0.5792 - val_auc: 0.6215 - val_recall_2: 0.9381 - val_true_negatives_2: 21.0000
# Epoch 14/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.9152 - accuracy: 0.6990 - precision: 0.7048 - auc: 0.7711 - recall_2: 0.7346 - true_negatives_2: 155.0000 - val_loss: 1.4929 - val_accuracy: 0.5403 - val_precision: 0.6111 - val_auc: 0.6359 - val_recall_2: 0.3894 - val_true_negatives_2: 70.0000
# Epoch 15/50
# 16/16 [==============================] - 32s 2s/step - loss: 0.9140 - accuracy: 0.7131 - precision: 0.7341 - auc: 0.7733 - recall_2: 0.7115 - true_negatives_2: 168.0000 - val_loss: 1.1973 - val_accuracy: 0.6161 - val_precision: 0.6176 - val_auc: 0.6182 - val_recall_2: 0.7434 - val_true_negatives_2: 46.0000
# Epoch 16/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.8179 - accuracy: 0.7273 - precision: 0.7432 - auc: 0.7884 - recall_2: 0.7346 - true_negatives_2: 169.0000 - val_loss: 2.5879 - val_accuracy: 0.5640 - val_precision: 0.5568 - val_auc: 0.5864 - val_recall_2: 0.9115 - val_true_negatives_2: 16.0000
# Epoch 17/50
# 16/16 [==============================] - 34s 2s/step - loss: 0.9367 - accuracy: 0.6828 - precision: 0.6914 - auc: 0.7622 - recall_2: 0.7154 - true_negatives_2: 152.0000 - val_loss: 1.3710 - val_accuracy: 0.5735 - val_precision: 0.5839 - val_auc: 0.5806 - val_recall_2: 0.7080 - val_true_negatives_2: 41.0000
# Epoch 18/50
# 16/16 [==============================] - 32s 2s/step - loss: 0.8042 - accuracy: 0.7131 - precision: 0.7379 - auc: 0.7863 - recall_2: 0.7038 - true_negatives_2: 170.0000 - val_loss: 1.7189 - val_accuracy: 0.5924 - val_precision: 0.5754 - val_auc: 0.5939 - val_recall_2: 0.9115 - val_true_negatives_2: 22.0000
# Epoch 19/50
# 16/16 [==============================] - 29s 2s/step - loss: 0.9230 - accuracy: 0.7273 - precision: 0.7273 - auc: 0.7822 - recall_2: 0.7692 - true_negatives_2: 160.0000 - val_loss: 1.4692 - val_accuracy: 0.5355 - val_precision: 0.6027 - val_auc: 0.6487 - val_recall_2: 0.3894 - val_true_negatives_2: 69.0000
# Epoch 20/50
# 16/16 [==============================] - 33s 2s/step - loss: 0.8697 - accuracy: 0.7131 - precision: 0.7269 - auc: 0.7756 - recall_2: 0.7269 - true_negatives_2: 164.0000 - val_loss: 1.1683 - val_accuracy: 0.6303 - val_precision: 0.6357 - val_auc: 0.6440 - val_recall_2: 0.7257 - val_true_negatives_2: 51.0000
# Epoch 21/50
# 16/16 [==============================] - 33s 2s/step - loss: 0.8260 - accuracy: 0.7333 - precision: 0.7462 - auc: 0.7978 - recall_2: 0.7462 - true_negatives_2: 169.0000 - val_loss: 1.3697 - val_accuracy: 0.5640 - val_precision: 0.6842 - val_auc: 0.6721 - val_recall_2: 0.3451 - val_true_negatives_2: 80.0000
# Epoch 22/50
# 16/16 [==============================] - 51s 3s/step - loss: 0.9702 - accuracy: 0.6990 - precision: 0.7143 - auc: 0.7598 - recall_2: 0.7115 - true_negatives_2: 161.0000 - val_loss: 1.5404 - val_accuracy: 0.6209 - val_precision: 0.5943 - val_auc: 0.6466 - val_recall_2: 0.9204 - val_true_negatives_2: 27.0000
# Epoch 23/50
# 16/16 [==============================] - 54s 3s/step - loss: 1.6477 - accuracy: 0.6323 - precision: 0.6489 - auc: 0.6934 - recall_2: 0.6538 - true_negatives_2: 143.0000 - val_loss: 2.2188 - val_accuracy: 0.6161 - val_precision: 0.6026 - val_auc: 0.6026 - val_recall_2: 0.8319 - val_true_negatives_2: 36.0000
# Epoch 24/50
# 16/16 [==============================] - 53s 3s/step - loss: 1.4685 - accuracy: 0.6667 - precision: 0.7056 - auc: 0.7277 - recall_2: 0.6269 - true_negatives_2: 167.0000 - val_loss: 3.0638 - val_accuracy: 0.5687 - val_precision: 0.5567 - val_auc: 0.6484 - val_recall_2: 0.9558 - val_true_negatives_2: 12.0000
# Epoch 25/50
# 16/16 [==============================] - 38s 2s/step - loss: 1.0822 - accuracy: 0.7131 - precision: 0.7169 - auc: 0.7667 - recall_2: 0.7500 - true_negatives_2: 158.0000 - val_loss: 1.3966 - val_accuracy: 0.6114 - val_precision: 0.6099 - val_auc: 0.6210 - val_recall_2: 0.7611 - val_true_negatives_2: 43.0000
# Epoch 26/50
# 16/16 [==============================] - 45s 3s/step - loss: 0.8634 - accuracy: 0.7455 - precision: 0.7724 - auc: 0.8038 - recall_2: 0.7308 - true_negatives_2: 179.0000 - val_loss: 1.3756 - val_accuracy: 0.5877 - val_precision: 0.5844 - val_auc: 0.5952 - val_recall_2: 0.7965 - val_true_negatives_2: 34.0000
# Epoch 27/50
# 16/16 [==============================] - 54s 3s/step - loss: 1.0187 - accuracy: 0.7010 - precision: 0.7137 - auc: 0.7717 - recall_2: 0.7192 - true_negatives_2: 160.0000 - val_loss: 2.4228 - val_accuracy: 0.4882 - val_precision: 0.6087 - val_auc: 0.6203 - val_recall_2: 0.1239 - val_true_negatives_2: 89.0000
# Epoch 28/50
# 16/16 [==============================] - 55s 3s/step - loss: 1.3825 - accuracy: 0.6768 - precision: 0.7083 - auc: 0.7471 - recall_2: 0.6538 - true_negatives_2: 165.0000 - val_loss: 1.9037 - val_accuracy: 0.6398 - val_precision: 0.6529 - val_auc: 0.6515 - val_recall_2: 0.6991 - val_true_negatives_2: 56.0000
# Epoch 29/50
# 16/16 [==============================] - 54s 3s/step - loss: 1.3836 - accuracy: 0.7071 - precision: 0.7328 - auc: 0.7613 - recall_2: 0.6962 - true_negatives_2: 169.0000 - val_loss: 3.9237 - val_accuracy: 0.5450 - val_precision: 0.5419 - val_auc: 0.6011 - val_recall_2: 0.9735 - val_true_negatives_2: 5.0000
# Epoch 30/50
# 16/16 [==============================] - 55s 3s/step - loss: 1.1468 - accuracy: 0.7293 - precision: 0.7351 - auc: 0.7861 - recall_2: 0.7577 - true_negatives_2: 164.0000 - val_loss: 4.2172 - val_accuracy: 0.5498 - val_precision: 0.5441 - val_auc: 0.5826 - val_recall_2: 0.9823 - val_true_negatives_2: 5.0000
# Epoch 31/50
# 16/16 [==============================] - 52s 3s/step - loss: 1.2524 - accuracy: 0.6828 - precision: 0.6973 - auc: 0.7630 - recall_2: 0.7000 - true_negatives_2: 156.0000 - val_loss: 3.4538 - val_accuracy: 0.5640 - val_precision: 0.5544 - val_auc: 0.6077 - val_recall_2: 0.9469 - val_true_negatives_2: 12.0000
# Epoch 32/50
# 16/16 [==============================] - 55s 3s/step - loss: 1.3281 - accuracy: 0.6626 - precision: 0.6703 - auc: 0.7526 - recall_2: 0.7038 - true_negatives_2: 145.0000 - val_loss: 2.2383 - val_accuracy: 0.6114 - val_precision: 0.5951 - val_auc: 0.5597 - val_recall_2: 0.8584 - val_true_negatives_2: 32.0000
# Epoch 33/50
# 16/16 [==============================] - 54s 3s/step - loss: 0.7348 - accuracy: 0.7778 - precision: 0.7863 - auc: 0.8458 - recall_2: 0.7923 - true_negatives_2: 179.0000 - val_loss: 1.6574 - val_accuracy: 0.5166 - val_precision: 0.5556 - val_auc: 0.5576 - val_recall_2: 0.4867 - val_true_negatives_2: 54.0000
# Epoch 34/50
# 16/16 [==============================] - 55s 3s/step - loss: 0.7505 - accuracy: 0.7475 - precision: 0.7626 - auc: 0.8258 - recall_2: 0.7538 - true_negatives_2: 174.0000 - val_loss: 1.6223 - val_accuracy: 0.5735 - val_precision: 0.5839 - val_auc: 0.5812 - val_recall_2: 0.7080 - val_true_negatives_2: 41.0000
# Epoch 35/50
# 16/16 [==============================] - 53s 3s/step - loss: 0.7934 - accuracy: 0.7414 - precision: 0.7519 - auc: 0.8190 - recall_2: 0.7577 - true_negatives_2: 170.0000 - val_loss: 1.7155 - val_accuracy: 0.6161 - val_precision: 0.6081 - val_auc: 0.5810 - val_recall_2: 0.7965 - val_true_negatives_2: 40.0000
# Epoch 36/50
# 16/16 [==============================] - 57s 4s/step - loss: 1.2185 - accuracy: 0.6848 - precision: 0.7131 - auc: 0.7654 - recall_2: 0.6692 - true_negatives_2: 165.0000 - val_loss: 2.0370 - val_accuracy: 0.5308 - val_precision: 0.5625 - val_auc: 0.5613 - val_recall_2: 0.5575 - val_true_negatives_2: 49.0000
# Epoch 37/50
# 16/16 [==============================] - 54s 3s/step - loss: 1.1650 - accuracy: 0.6788 - precision: 0.7113 - auc: 0.7509 - recall_2: 0.6538 - true_negatives_2: 166.0000 - val_loss: 2.8882 - val_accuracy: 0.5829 - val_precision: 0.5668 - val_auc: 0.5790 - val_recall_2: 0.9381 - val_true_negatives_2: 17.0000
# Epoch 38/50
# 16/16 [==============================] - 57s 4s/step - loss: 1.1116 - accuracy: 0.7212 - precision: 0.7293 - auc: 0.7880 - recall_2: 0.7462 - true_negatives_2: 163.0000 - val_loss: 3.1746 - val_accuracy: 0.5735 - val_precision: 0.5628 - val_auc: 0.5877 - val_recall_2: 0.9115 - val_true_negatives_2: 18.0000
# Epoch 39/50
# 16/16 [==============================] - 34s 2s/step - loss: 0.7590 - accuracy: 0.7596 - precision: 0.7601 - auc: 0.8357 - recall_2: 0.7923 - true_negatives_2: 170.0000 - val_loss: 2.0293 - val_accuracy: 0.5118 - val_precision: 0.5403 - val_auc: 0.5057 - val_recall_2: 0.5929 - val_true_negatives_2: 41.0000
# Epoch 40/50
# 16/16 [==============================] - 53s 3s/step - loss: 0.9289 - accuracy: 0.7131 - precision: 0.7360 - auc: 0.7844 - recall_2: 0.7077 - true_negatives_2: 169.0000 - val_loss: 2.0473 - val_accuracy: 0.5213 - val_precision: 0.5526 - val_auc: 0.5003 - val_recall_2: 0.5575 - val_true_negatives_2: 47.0000
# Epoch 41/50
# 16/16 [==============================] - 53s 3s/step - loss: 1.0841 - accuracy: 0.7030 - precision: 0.7055 - auc: 0.7823 - recall_2: 0.7462 - true_negatives_2: 154.0000 - val_loss: 4.1506 - val_accuracy: 0.5592 - val_precision: 0.5490 - val_auc: 0.5123 - val_recall_2: 0.9912 - val_true_negatives_2: 6.0000
# Epoch 42/50
# 16/16 [==============================] - 56s 4s/step - loss: 0.8769 - accuracy: 0.7333 - precision: 0.7500 - auc: 0.8081 - recall_2: 0.7385 - true_negatives_2: 171.0000 - val_loss: 4.6183 - val_accuracy: 0.5545 - val_precision: 0.5459 - val_auc: 0.5489 - val_recall_2: 1.0000 - val_true_negatives_2: 4.0000
# Epoch 43/50
# 16/16 [==============================] - 53s 3s/step - loss: 1.2445 - accuracy: 0.7051 - precision: 0.7080 - auc: 0.7818 - recall_2: 0.7462 - true_negatives_2: 155.0000 - val_loss: 2.2729 - val_accuracy: 0.6019 - val_precision: 0.6058 - val_auc: 0.5519 - val_recall_2: 0.7345 - val_true_negatives_2: 44.0000
# Epoch 44/50
# 16/16 [==============================] - 56s 4s/step - loss: 1.1144 - accuracy: 0.6990 - precision: 0.7126 - auc: 0.7701 - recall_2: 0.7154 - true_negatives_2: 160.0000 - val_loss: 2.3882 - val_accuracy: 0.5592 - val_precision: 0.5847 - val_auc: 0.5435 - val_recall_2: 0.6106 - val_true_negatives_2: 49.0000
# Epoch 45/50
# 16/16 [==============================] - 54s 3s/step - loss: 0.9716 - accuracy: 0.7212 - precision: 0.7480 - auc: 0.7974 - recall_2: 0.7077 - true_negatives_2: 173.0000 - val_loss: 2.6816 - val_accuracy: 0.5735 - val_precision: 0.5706 - val_auc: 0.5493 - val_recall_2: 0.8230 - val_true_negatives_2: 28.0000
# Epoch 46/50
# 16/16 [==============================] - 53s 3s/step - loss: 0.9692 - accuracy: 0.7172 - precision: 0.7400 - auc: 0.7970 - recall_2: 0.7115 - true_negatives_2: 170.0000 - val_loss: 2.3685 - val_accuracy: 0.5877 - val_precision: 0.5774 - val_auc: 0.5381 - val_recall_2: 0.8584 - val_true_negatives_2: 27.0000
# Epoch 47/50
# 16/16 [==============================] - 56s 3s/step - loss: 0.9742 - accuracy: 0.7172 - precision: 0.7158 - auc: 0.7978 - recall_2: 0.7654 - true_negatives_2: 156.0000 - val_loss: 2.3742 - val_accuracy: 0.5782 - val_precision: 0.5732 - val_auc: 0.5582 - val_recall_2: 0.8319 - val_true_negatives_2: 28.0000
# Epoch 48/50
# 16/16 [==============================] - 52s 3s/step - loss: 0.9989 - accuracy: 0.7354 - precision: 0.7471 - auc: 0.8116 - recall_2: 0.7500 - true_negatives_2: 169.0000 - val_loss: 3.0731 - val_accuracy: 0.5640 - val_precision: 0.5550 - val_auc: 0.5522 - val_recall_2: 0.9381 - val_true_negatives_2: 13.0000
# Epoch 49/50
# 16/16 [==============================] - 55s 3s/step - loss: 0.9856 - accuracy: 0.7354 - precision: 0.7452 - auc: 0.8152 - recall_2: 0.7538 - true_negatives_2: 168.0000 - val_loss: 2.9924 - val_accuracy: 0.5545 - val_precision: 0.5482 - val_auc: 0.5408 - val_recall_2: 0.9558 - val_true_negatives_2: 9.0000
# Epoch 50/50
# 16/16 [==============================] - 53s 3s/step - loss: 1.0082 - accuracy: 0.7131 - precision: 0.7269 - auc: 0.7971 - recall_2: 0.7269 - true_negatives_2: 164.0000 - val_loss: 2.6712 - val_accuracy: 0.5592 - val_precision: 0.5581 - val_auc: 0.5421 - val_recall_2: 0.8496 - val_true_negatives_2: 22.0000

# %%
import statistics
print (statistics.mean(history.history['accuracy']))
print (statistics.mean(history.history['val_accuracy']))
# Out:
# 0.6981818211078644
# 0.5805687224864959

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 12s 2s/step - loss: 2.6712 - accuracy: 0.5592 - precision: 0.5581 - auc: 0.5421 - recall_2: 0.8496 - true_negatives_2: 22.0000
# [2.6711647510528564,
#  0.5592417120933533,
#  0.5581395626068115,
#  0.5421257019042969,
#  0.8495575189590454,
#  22.0]
