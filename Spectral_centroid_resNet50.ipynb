# %% [markdown]
# # Spectral_centroid_resNet50

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras import optimizers, losses, activations, models
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
train_path= 'C:/Users/ASUS/Desktop/res_spectral_centroid/train'
test_path= 'C:/Users/ASUS/Desktop/res_spectral_centroid/test'
class_names=os.listdir(train_path)
class_names_test=os.listdir(test_path)

# %%
print(class_names)
print(class_names_test)
# Out:
# ['abnormal', 'normal']
# ['abnormal', 'normal']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15)
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory('C:/Users/ASUS/Desktop/res_spectral_centroid/train',target_size=(224, 224),batch_size=32,shuffle=True,class_mode='binary')
test_generator = test_datagen.flow_from_directory('C:/Users/ASUS/Desktop/res_spectral_centroid/test',target_size=(224,224),batch_size=32,shuffle=False,class_mode='binary')
# Out:
# Found 495 images belonging to 2 classes.
# Found 211 images belonging to 2 classes.

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(224, 224, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 1,activation='sigmoid', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          8388864     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 1)            129         ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 32,009,601
# Trainable params: 31,956,481
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# weight_path="{}_weights.best.hdf5".format('spectro_sound_model')
checkpoint = ModelCheckpoint(filepath ="./check.hDf5", monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)
# reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', 
#                                    factor=0.8, patience=5, 
#                                    verbose=1, mode='auto', 
#                                    epsilon=0.0001, cooldown=5, 
#                                    min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early]

# %%
import tensorflow as tf
from keras.models import *
from keras.layers import *
opt = tf.optimizers.Adam(lr=1e-3)
model.compile(optimizer=opt, 
    loss=losses.binary_crossentropy, 
    metrics=['accuracy', 'Precision', 'AUC', tf.keras.metrics.Recall(), tf.keras.metrics.TrueNegatives()])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
training_images = 456
validation_images = 144 

history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results. 
                   epochs = 50,  # change this for better results
                   validation_data = test_generator)  # this should be equal to total number of images in validation set.
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_3400/615836474.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results.
# Epoch 1/50
# 16/16 [==============================] - 216s 13s/step - loss: 7.0522 - accuracy: 0.5091 - precision: 0.5290 - auc: 0.5100 - recall: 0.5962 - true_negatives: 97.0000 - val_loss: 251148.4688 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 2/50
# 16/16 [==============================] - 232s 15s/step - loss: 1.3665 - accuracy: 0.4929 - precision: 0.5187 - auc: 0.5165 - recall: 0.4808 - true_negatives: 119.0000 - val_loss: 2975.2615 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 3/50
# 16/16 [==============================] - 243s 15s/step - loss: 0.9513 - accuracy: 0.4808 - precision: 0.5052 - auc: 0.4876 - recall: 0.5577 - true_negatives: 93.0000 - val_loss: 38548.4414 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 4/50
# 16/16 [==============================] - 222s 14s/step - loss: 0.8593 - accuracy: 0.5475 - precision: 0.5677 - auc: 0.5745 - recall: 0.5808 - true_negatives: 120.0000 - val_loss: 12102.2578 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 5/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.8323 - accuracy: 0.5374 - precision: 0.5649 - auc: 0.5635 - recall: 0.5192 - true_negatives: 131.0000 - val_loss: 3569.3401 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 6/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.9806 - accuracy: 0.5354 - precision: 0.5556 - auc: 0.5607 - recall: 0.5769 - true_negatives: 115.0000 - val_loss: 1169.1508 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4955 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 7/50
# 16/16 [==============================] - 230s 15s/step - loss: 1.1396 - accuracy: 0.5293 - precision: 0.5495 - auc: 0.5438 - recall: 0.5769 - true_negatives: 112.0000 - val_loss: 91.9624 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 8/50
# 16/16 [==============================] - 210s 13s/step - loss: 1.2537 - accuracy: 0.5556 - precision: 0.5943 - auc: 0.5541 - recall: 0.4846 - true_negatives: 149.0000 - val_loss: 4.6214 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4205 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 9/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.8710 - accuracy: 0.4525 - precision: 0.4834 - auc: 0.4501 - recall: 0.6154 - true_negatives: 64.0000 - val_loss: 13.9144 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.5041 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 10/50
# 16/16 [==============================] - 194s 12s/step - loss: 0.9837 - accuracy: 0.4606 - precision: 0.4881 - auc: 0.4629 - recall: 0.5500 - true_negatives: 85.0000 - val_loss: 6.4288 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4664 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 11/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.7585 - accuracy: 0.5111 - precision: 0.5352 - auc: 0.5512 - recall: 0.5269 - true_negatives: 116.0000 - val_loss: 1.1151 - val_accuracy: 0.5687 - val_precision: 0.8125 - val_auc: 0.6695 - val_recall: 0.2342 - val_true_negatives: 94.0000
# Epoch 12/50
# 16/16 [==============================] - 190s 12s/step - loss: 0.7724 - accuracy: 0.5152 - precision: 0.5299 - auc: 0.5356 - recall: 0.6808 - true_negatives: 78.0000 - val_loss: 93.6035 - val_accuracy: 0.4360 - val_precision: 0.4780 - val_auc: 0.4082 - val_recall: 0.7838 - val_true_negatives: 5.0000
# Epoch 13/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.7574 - accuracy: 0.5071 - precision: 0.5367 - auc: 0.5422 - recall: 0.4500 - true_negatives: 134.0000 - val_loss: 88.6281 - val_accuracy: 0.5166 - val_precision: 0.5215 - val_auc: 0.4059 - val_recall: 0.9820 - val_true_negatives: 0.0000e+00
# Epoch 14/50
# 16/16 [==============================] - 200s 12s/step - loss: 0.8393 - accuracy: 0.5394 - precision: 0.5755 - auc: 0.5668 - recall: 0.4692 - true_negatives: 145.0000 - val_loss: 3.9563 - val_accuracy: 0.4455 - val_precision: 0.4786 - val_auc: 0.3788 - val_recall: 0.6036 - val_true_negatives: 27.0000
# Epoch 15/50
# 16/16 [==============================] - 210s 13s/step - loss: 0.7008 - accuracy: 0.5960 - precision: 0.5820 - auc: 0.6257 - recall: 0.8192 - true_negatives: 82.0000 - val_loss: 1.0942 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.6036 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 16/50
# 16/16 [==============================] - 207s 13s/step - loss: 0.7181 - accuracy: 0.6162 - precision: 0.6296 - auc: 0.6544 - recall: 0.6538 - true_negatives: 135.0000 - val_loss: 1.3503 - val_accuracy: 0.4123 - val_precision: 0.4601 - val_auc: 0.4418 - val_recall: 0.6757 - val_true_negatives: 12.0000
# Epoch 17/50
# 16/16 [==============================] - 206s 13s/step - loss: 0.7557 - accuracy: 0.5980 - precision: 0.6134 - auc: 0.6231 - recall: 0.6346 - true_negatives: 131.0000 - val_loss: 4.0904 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.3900 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 18/50
# 16/16 [==============================] - 194s 13s/step - loss: 0.7033 - accuracy: 0.6202 - precision: 0.6286 - auc: 0.6629 - recall: 0.6769 - true_negatives: 131.0000 - val_loss: 5.6530 - val_accuracy: 0.4550 - val_precision: 0.4855 - val_auc: 0.4163 - val_recall: 0.6036 - val_true_negatives: 29.0000
# Epoch 19/50
# 16/16 [==============================] - 180s 11s/step - loss: 0.6359 - accuracy: 0.6323 - precision: 0.6711 - auc: 0.6850 - recall: 0.5885 - true_negatives: 160.0000 - val_loss: 7.7319 - val_accuracy: 0.4597 - val_precision: 0.4922 - val_auc: 0.4281 - val_recall: 0.8559 - val_true_negatives: 2.0000
# Epoch 20/50
# 16/16 [==============================] - 179s 11s/step - loss: 0.6440 - accuracy: 0.5859 - precision: 0.6054 - auc: 0.6569 - recall: 0.6077 - true_negatives: 132.0000 - val_loss: 6.1280 - val_accuracy: 0.4597 - val_precision: 0.4892 - val_auc: 0.4444 - val_recall: 0.6126 - val_true_negatives: 29.0000
# Epoch 21/50
# 16/16 [==============================] - 182s 11s/step - loss: 0.6047 - accuracy: 0.6404 - precision: 0.6306 - auc: 0.7303 - recall: 0.7615 - true_negatives: 119.0000 - val_loss: 4.4264 - val_accuracy: 0.4597 - val_precision: 0.4891 - val_auc: 0.4532 - val_recall: 0.6036 - val_true_negatives: 30.0000
# Epoch 22/50
# 16/16 [==============================] - 186s 11s/step - loss: 0.6089 - accuracy: 0.6586 - precision: 0.7116 - auc: 0.7182 - recall: 0.5885 - true_negatives: 173.0000 - val_loss: 2.2936 - val_accuracy: 0.4645 - val_precision: 0.4926 - val_auc: 0.4700 - val_recall: 0.6036 - val_true_negatives: 31.0000
# Epoch 23/50
# 16/16 [==============================] - 183s 11s/step - loss: 0.6398 - accuracy: 0.6384 - precision: 0.6738 - auc: 0.6914 - recall: 0.6038 - true_negatives: 159.0000 - val_loss: 2.4714 - val_accuracy: 0.4645 - val_precision: 0.4926 - val_auc: 0.4258 - val_recall: 0.6036 - val_true_negatives: 31.0000
# Epoch 24/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.6062 - accuracy: 0.6384 - precision: 0.6769 - auc: 0.7198 - recall: 0.5962 - true_negatives: 161.0000 - val_loss: 4.6387 - val_accuracy: 0.4455 - val_precision: 0.4828 - val_auc: 0.3958 - val_recall: 0.7568 - val_true_negatives: 10.0000
# Epoch 25/50
# 16/16 [==============================] - 179s 12s/step - loss: 0.6560 - accuracy: 0.6000 - precision: 0.5886 - auc: 0.6691 - recall: 0.7923 - true_negatives: 91.0000 - val_loss: 4.3517 - val_accuracy: 0.5071 - val_precision: 0.5310 - val_auc: 0.4039 - val_recall: 0.5405 - val_true_negatives: 47.0000
# Epoch 26/50
# 16/16 [==============================] - 177s 11s/step - loss: 0.6105 - accuracy: 0.6869 - precision: 0.7397 - auc: 0.7335 - recall: 0.6231 - true_negatives: 178.0000 - val_loss: 1.9909 - val_accuracy: 0.4692 - val_precision: 0.4973 - val_auc: 0.4017 - val_recall: 0.8198 - val_true_negatives: 8.0000
# Epoch 27/50
# 16/16 [==============================] - 179s 11s/step - loss: 0.5923 - accuracy: 0.6606 - precision: 0.6503 - auc: 0.7457 - recall: 0.7654 - true_negatives: 128.0000 - val_loss: 0.8019 - val_accuracy: 0.4455 - val_precision: 0.4817 - val_auc: 0.4044 - val_recall: 0.7117 - val_true_negatives: 15.0000
# Epoch 28/50
# 16/16 [==============================] - 178s 11s/step - loss: 0.6627 - accuracy: 0.6384 - precision: 0.6653 - auc: 0.6970 - recall: 0.6269 - true_negatives: 153.0000 - val_loss: 1.3116 - val_accuracy: 0.4502 - val_precision: 0.4845 - val_auc: 0.4120 - val_recall: 0.7027 - val_true_negatives: 17.0000
# Epoch 29/50
# 16/16 [==============================] - 178s 11s/step - loss: 0.6273 - accuracy: 0.6525 - precision: 0.6719 - auc: 0.7023 - recall: 0.6615 - true_negatives: 151.0000 - val_loss: 1.4688 - val_accuracy: 0.4502 - val_precision: 0.4850 - val_auc: 0.4007 - val_recall: 0.7297 - val_true_negatives: 14.0000
# Epoch 30/50
# 16/16 [==============================] - 177s 11s/step - loss: 0.6236 - accuracy: 0.6444 - precision: 0.6654 - auc: 0.6940 - recall: 0.6500 - true_negatives: 150.0000 - val_loss: 1.4549 - val_accuracy: 0.4834 - val_precision: 0.5055 - val_auc: 0.3706 - val_recall: 0.8288 - val_true_negatives: 10.0000
# Epoch 31/50
# 16/16 [==============================] - 187s 12s/step - loss: 0.6117 - accuracy: 0.6586 - precision: 0.6311 - auc: 0.7244 - recall: 0.8423 - true_negatives: 107.0000 - val_loss: 1.2573 - val_accuracy: 0.4455 - val_precision: 0.4815 - val_auc: 0.4043 - val_recall: 0.7027 - val_true_negatives: 16.0000
# Epoch 32/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.6484 - accuracy: 0.6081 - precision: 0.6019 - auc: 0.6974 - recall: 0.7500 - true_negatives: 106.0000 - val_loss: 2.0464 - val_accuracy: 0.4550 - val_precision: 0.4878 - val_auc: 0.3677 - val_recall: 0.7207 - val_true_negatives: 16.0000
# Epoch 33/50
# 16/16 [==============================] - 194s 12s/step - loss: 0.6245 - accuracy: 0.6485 - precision: 0.6838 - auc: 0.7162 - recall: 0.6154 - true_negatives: 161.0000 - val_loss: 1.7054 - val_accuracy: 0.4218 - val_precision: 0.4580 - val_auc: 0.3514 - val_recall: 0.5405 - val_true_negatives: 29.0000
# Epoch 34/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6489 - accuracy: 0.6121 - precision: 0.5994 - auc: 0.6851 - recall: 0.7885 - true_negatives: 98.0000 - val_loss: 1.2492 - val_accuracy: 0.4834 - val_precision: 0.5056 - val_auc: 0.3465 - val_recall: 0.8198 - val_true_negatives: 11.0000
# Epoch 35/50
# 16/16 [==============================] - 189s 12s/step - loss: 0.6343 - accuracy: 0.6465 - precision: 0.6735 - auc: 0.7012 - recall: 0.6346 - true_negatives: 155.0000 - val_loss: 1.1321 - val_accuracy: 0.4597 - val_precision: 0.4916 - val_auc: 0.3491 - val_recall: 0.7928 - val_true_negatives: 9.0000
# Epoch 36/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.6265 - accuracy: 0.6545 - precision: 0.6261 - auc: 0.7158 - recall: 0.8500 - true_negatives: 103.0000 - val_loss: 0.8123 - val_accuracy: 0.4360 - val_precision: 0.4730 - val_auc: 0.3527 - val_recall: 0.6306 - val_true_negatives: 22.0000
# Epoch 37/50
# 16/16 [==============================] - 184s 12s/step - loss: 0.6342 - accuracy: 0.6384 - precision: 0.6653 - auc: 0.6922 - recall: 0.6269 - true_negatives: 153.0000 - val_loss: 0.8297 - val_accuracy: 0.5261 - val_precision: 0.5266 - val_auc: 0.3708 - val_recall: 0.9820 - val_true_negatives: 2.0000
# Epoch 38/50
# 16/16 [==============================] - 184s 12s/step - loss: 0.6159 - accuracy: 0.6606 - precision: 0.6840 - auc: 0.7069 - recall: 0.6577 - true_negatives: 156.0000 - val_loss: 0.8895 - val_accuracy: 0.4645 - val_precision: 0.4940 - val_auc: 0.3428 - val_recall: 0.7477 - val_true_negatives: 15.0000
# Epoch 39/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6275 - accuracy: 0.6747 - precision: 0.6800 - auc: 0.7166 - recall: 0.7192 - true_negatives: 147.0000 - val_loss: 0.9765 - val_accuracy: 0.5071 - val_precision: 0.5181 - val_auc: 0.3571 - val_recall: 0.9009 - val_true_negatives: 7.0000
# Epoch 40/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6121 - accuracy: 0.6687 - precision: 0.6890 - auc: 0.7345 - recall: 0.6731 - true_negatives: 156.0000 - val_loss: 1.4539 - val_accuracy: 0.5355 - val_precision: 0.5317 - val_auc: 0.3848 - val_recall: 0.9820 - val_true_negatives: 4.0000
# Epoch 41/50
# 16/16 [==============================] - 180s 11s/step - loss: 0.6137 - accuracy: 0.6586 - precision: 0.6730 - auc: 0.7206 - recall: 0.6808 - true_negatives: 149.0000 - val_loss: 1.2141 - val_accuracy: 0.4882 - val_precision: 0.5079 - val_auc: 0.3737 - val_recall: 0.8739 - val_true_negatives: 6.0000
# Epoch 42/50
# 16/16 [==============================] - 179s 11s/step - loss: 0.5999 - accuracy: 0.6687 - precision: 0.6655 - auc: 0.7464 - recall: 0.7423 - true_negatives: 138.0000 - val_loss: 0.9176 - val_accuracy: 0.4645 - val_precision: 0.4943 - val_auc: 0.3358 - val_recall: 0.7748 - val_true_negatives: 12.0000
# Epoch 43/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.5666 - accuracy: 0.6848 - precision: 0.6757 - auc: 0.7594 - recall: 0.7692 - true_negatives: 139.0000 - val_loss: 1.2379 - val_accuracy: 0.5261 - val_precision: 0.5279 - val_auc: 0.4397 - val_recall: 0.9369 - val_true_negatives: 7.0000
# Epoch 44/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6272 - accuracy: 0.6525 - precision: 0.6571 - auc: 0.6937 - recall: 0.7077 - true_negatives: 139.0000 - val_loss: 1.3086 - val_accuracy: 0.5071 - val_precision: 0.5179 - val_auc: 0.3609 - val_recall: 0.9099 - val_true_negatives: 6.0000
# Epoch 45/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.6027 - accuracy: 0.6606 - precision: 0.6679 - auc: 0.7402 - recall: 0.7038 - true_negatives: 144.0000 - val_loss: 1.3131 - val_accuracy: 0.4455 - val_precision: 0.4828 - val_auc: 0.3693 - val_recall: 0.7568 - val_true_negatives: 10.0000
# Epoch 46/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.5841 - accuracy: 0.6949 - precision: 0.6873 - auc: 0.7601 - recall: 0.7692 - true_negatives: 144.0000 - val_loss: 1.6978 - val_accuracy: 0.4502 - val_precision: 0.4852 - val_auc: 0.3553 - val_recall: 0.7387 - val_true_negatives: 13.0000
# Epoch 47/50
# 16/16 [==============================] - 187s 12s/step - loss: 0.5958 - accuracy: 0.6828 - precision: 0.6943 - auc: 0.7432 - recall: 0.7077 - true_negatives: 154.0000 - val_loss: 2.0622 - val_accuracy: 0.4550 - val_precision: 0.4881 - val_auc: 0.3497 - val_recall: 0.7387 - val_true_negatives: 14.0000
# Epoch 48/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.5651 - accuracy: 0.6828 - precision: 0.6943 - auc: 0.7748 - recall: 0.7077 - true_negatives: 154.0000 - val_loss: 1.0006 - val_accuracy: 0.4550 - val_precision: 0.4877 - val_auc: 0.3509 - val_recall: 0.7117 - val_true_negatives: 17.0000
# Epoch 49/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.5901 - accuracy: 0.6909 - precision: 0.7034 - auc: 0.7494 - recall: 0.7115 - true_negatives: 157.0000 - val_loss: 0.8364 - val_accuracy: 0.4360 - val_precision: 0.4744 - val_auc: 0.3474 - val_recall: 0.6667 - val_true_negatives: 18.0000
# Epoch 50/50
# 16/16 [==============================] - 181s 11s/step - loss: 0.5818 - accuracy: 0.6848 - precision: 0.6769 - auc: 0.7518 - recall: 0.7654 - true_negatives: 140.0000 - val_loss: 1.8677 - val_accuracy: 0.5261 - val_precision: 0.5263 - val_auc: 0.4200 - val_recall: 0.9910 - val_true_negatives: 1.0000

# %%
import statistics
print (statistics.mean(history.history['accuracy']))
print (statistics.mean(history.history['val_accuracy']))
# Out:
# 0.6102626305818558
# 0.47971564054489135

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 14s 2s/step - loss: 0.6471 - accuracy: 0.5735 - precision: 0.5533 - auc: 0.7733 - recall: 0.9820 - true_negatives: 12.0000
# [0.6470789909362793,
#  0.5734597444534302,
#  0.5532994866371155,
#  0.7732882499694824,
#  0.9819819927215576,
#  12.0]
