# %% [markdown]
# # Raw_data_resNet50

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras import optimizers, losses, activations, models
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
train_path= 'C:/Users/ASUS/Desktop/resWave/train'
test_path= 'C:/Users/ASUS/Desktop/resWave/test'
class_names=os.listdir(train_path)
class_names_test=os.listdir(test_path)

# %%
print(class_names)
print(class_names_test)
# Out:
# ['abnormal', 'normal']
# ['abnormal', 'normal']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15)
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory('C:/Users/ASUS/Desktop/resWave/train',target_size=(224, 224),batch_size=32,shuffle=True,class_mode='binary')
test_generator = test_datagen.flow_from_directory('C:/Users/ASUS/Desktop/resWave/test',target_size=(224,224),batch_size=32,shuffle=False,class_mode='binary')
# Out:
# Found 495 images belonging to 2 classes.
# Found 211 images belonging to 2 classes.

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(224, 224, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 1,activation='sigmoid', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          8388864     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 1)            129         ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 32,009,601
# Trainable params: 31,956,481
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# weight_path="{}_weights.best.hdf5".format('spectro_sound_model')
checkpoint = ModelCheckpoint(filepath ="./check.hDf5", monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)
# reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', 
#                                    factor=0.8, patience=5, 
#                                    verbose=1, mode='auto', 
#                                    epsilon=0.0001, cooldown=5, 
#                                    min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early]

# %%
import tensorflow as tf
from keras.models import *
from keras.layers import *
opt = tf.optimizers.Adam(lr=1e-3)
model.compile(optimizer=opt, 
    loss=losses.binary_crossentropy, 
    metrics=['accuracy', 'Precision', 'AUC', tf.keras.metrics.Recall(), tf.keras.metrics.TrueNegatives()])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
training_images = 456
validation_images = 144 

history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results. 
                   epochs = 50,  # change this for better results
                   validation_data = test_generator)  # this should be equal to total number of images in validation set.
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_17888/615836474.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results.
# Epoch 1/50
# 16/16 [==============================] - 191s 12s/step - loss: 7.2465 - accuracy: 0.4828 - precision: 0.5075 - auc: 0.4706 - recall: 0.5231 - true_negatives: 103.0000 - val_loss: 28992.2090 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 2/50
# 16/16 [==============================] - 175s 11s/step - loss: 1.2127 - accuracy: 0.5071 - precision: 0.5267 - auc: 0.4965 - recall: 0.6077 - true_negatives: 93.0000 - val_loss: 703.3524 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 3/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.8320 - accuracy: 0.4747 - precision: 0.5000 - auc: 0.4431 - recall: 0.5692 - true_negatives: 87.0000 - val_loss: 114.9375 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 4/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.7033 - accuracy: 0.5374 - precision: 0.5460 - auc: 0.5656 - recall: 0.7077 - true_negatives: 82.0000 - val_loss: 24.6083 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4924 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 5/50
# 16/16 [==============================] - 184s 11s/step - loss: 0.7279 - accuracy: 0.5434 - precision: 0.5708 - auc: 0.5621 - recall: 0.5269 - true_negatives: 132.0000 - val_loss: 0.8680 - val_accuracy: 0.4597 - val_precision: 0.4842 - val_auc: 0.4224 - val_recall: 0.4144 - val_true_negatives: 51.0000
# Epoch 6/50
# 16/16 [==============================] - 183s 11s/step - loss: 1.0425 - accuracy: 0.5354 - precision: 0.5595 - auc: 0.5485 - recall: 0.5423 - true_negatives: 124.0000 - val_loss: 0.7711 - val_accuracy: 0.4313 - val_precision: 0.0000e+00 - val_auc: 0.3571 - val_recall: 0.0000e+00 - val_true_negatives: 91.0000
# Epoch 7/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.8716 - accuracy: 0.4768 - precision: 0.5018 - auc: 0.5014 - recall: 0.5346 - true_negatives: 97.0000 - val_loss: 0.7203 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.3462 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 8/50
# 16/16 [==============================] - 190s 12s/step - loss: 0.7042 - accuracy: 0.5212 - precision: 0.5622 - auc: 0.5489 - recall: 0.4000 - true_negatives: 154.0000 - val_loss: 0.7259 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.4337 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 9/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.8655 - accuracy: 0.5232 - precision: 0.5395 - auc: 0.5271 - recall: 0.6308 - true_negatives: 95.0000 - val_loss: 0.6939 - val_accuracy: 0.5213 - val_precision: 0.5238 - val_auc: 0.4553 - val_recall: 0.9910 - val_true_negatives: 0.0000e+00
# Epoch 10/50
# 16/16 [==============================] - 185s 12s/step - loss: 0.7008 - accuracy: 0.5374 - precision: 0.5689 - auc: 0.5400 - recall: 0.4923 - true_negatives: 138.0000 - val_loss: 0.6925 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4564 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 11/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.6720 - accuracy: 0.5556 - precision: 0.5500 - auc: 0.6017 - recall: 0.8462 - true_negatives: 55.0000 - val_loss: 0.6950 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.4590 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 12/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6833 - accuracy: 0.5576 - precision: 0.6171 - auc: 0.5935 - recall: 0.4154 - true_negatives: 168.0000 - val_loss: 0.6954 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.4585 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 13/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6546 - accuracy: 0.5980 - precision: 0.6649 - auc: 0.6511 - recall: 0.4731 - true_negatives: 173.0000 - val_loss: 0.6969 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4323 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 14/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.6442 - accuracy: 0.5879 - precision: 0.6094 - auc: 0.6408 - recall: 0.6000 - true_negatives: 135.0000 - val_loss: 0.7026 - val_accuracy: 0.4929 - val_precision: 0.5213 - val_auc: 0.4197 - val_recall: 0.4414 - val_true_negatives: 55.0000
# Epoch 15/50
# 16/16 [==============================] - 181s 11s/step - loss: 0.6333 - accuracy: 0.6364 - precision: 0.6786 - auc: 0.6936 - recall: 0.5846 - true_negatives: 163.0000 - val_loss: 0.7023 - val_accuracy: 0.4597 - val_precision: 0.4917 - val_auc: 0.3549 - val_recall: 0.8018 - val_true_negatives: 8.0000
# Epoch 16/50
# 16/16 [==============================] - 192s 12s/step - loss: 0.6462 - accuracy: 0.6222 - precision: 0.6594 - auc: 0.6586 - recall: 0.5808 - true_negatives: 157.0000 - val_loss: 0.7121 - val_accuracy: 0.4360 - val_precision: 0.4661 - val_auc: 0.3623 - val_recall: 0.4955 - val_true_negatives: 37.0000
# Epoch 17/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6307 - accuracy: 0.6424 - precision: 0.6708 - auc: 0.6770 - recall: 0.6269 - true_negatives: 155.0000 - val_loss: 0.7348 - val_accuracy: 0.4408 - val_precision: 0.1818 - val_auc: 0.3500 - val_recall: 0.0180 - val_true_negatives: 91.0000
# Epoch 18/50
# 16/16 [==============================] - 182s 11s/step - loss: 0.6154 - accuracy: 0.6424 - precision: 0.6861 - auc: 0.7127 - recall: 0.5885 - true_negatives: 165.0000 - val_loss: 0.7098 - val_accuracy: 0.4408 - val_precision: 0.4774 - val_auc: 0.3626 - val_recall: 0.6667 - val_true_negatives: 19.0000
# Epoch 19/50
# 16/16 [==============================] - 184s 12s/step - loss: 0.6306 - accuracy: 0.6283 - precision: 0.6557 - auc: 0.6733 - recall: 0.6154 - true_negatives: 151.0000 - val_loss: 0.7147 - val_accuracy: 0.4265 - val_precision: 0.4545 - val_auc: 0.3769 - val_recall: 0.4505 - val_true_negatives: 40.0000
# Epoch 20/50
# 16/16 [==============================] - 195s 12s/step - loss: 0.6016 - accuracy: 0.6667 - precision: 0.6834 - auc: 0.7414 - recall: 0.6808 - true_negatives: 153.0000 - val_loss: 0.7317 - val_accuracy: 0.4692 - val_precision: 0.4972 - val_auc: 0.3560 - val_recall: 0.8018 - val_true_negatives: 10.0000
# Epoch 21/50
# 16/16 [==============================] - 189s 12s/step - loss: 0.6664 - accuracy: 0.6141 - precision: 0.6507 - auc: 0.6738 - recall: 0.5731 - true_negatives: 155.0000 - val_loss: 0.7491 - val_accuracy: 0.3839 - val_precision: 0.4059 - val_auc: 0.3410 - val_recall: 0.3694 - val_true_negatives: 40.0000
# Epoch 22/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.5913 - accuracy: 0.6808 - precision: 0.7277 - auc: 0.7397 - recall: 0.6269 - true_negatives: 174.0000 - val_loss: 0.7650 - val_accuracy: 0.4976 - val_precision: 0.5137 - val_auc: 0.3552 - val_recall: 0.8468 - val_true_negatives: 11.0000
# Epoch 23/50
# 16/16 [==============================] - 195s 12s/step - loss: 0.6131 - accuracy: 0.6404 - precision: 0.6614 - auc: 0.7099 - recall: 0.6462 - true_negatives: 149.0000 - val_loss: 0.7769 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.3521 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 24/50
# 16/16 [==============================] - 192s 12s/step - loss: 0.6577 - accuracy: 0.5818 - precision: 0.5957 - auc: 0.6274 - recall: 0.6346 - true_negatives: 123.0000 - val_loss: 0.7185 - val_accuracy: 0.4502 - val_precision: 0.4837 - val_auc: 0.3409 - val_recall: 0.6667 - val_true_negatives: 21.0000
# Epoch 25/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6439 - accuracy: 0.6566 - precision: 0.6500 - auc: 0.7251 - recall: 0.7500 - true_negatives: 130.0000 - val_loss: 0.7675 - val_accuracy: 0.5545 - val_precision: 0.5419 - val_auc: 0.3468 - val_recall: 0.9910 - val_true_negatives: 7.0000
# Epoch 26/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.6203 - accuracy: 0.6222 - precision: 0.6174 - auc: 0.7116 - recall: 0.7385 - true_negatives: 116.0000 - val_loss: 0.8144 - val_accuracy: 0.5498 - val_precision: 0.5400 - val_auc: 0.3517 - val_recall: 0.9730 - val_true_negatives: 8.0000
# Epoch 27/50
# 16/16 [==============================] - 178s 11s/step - loss: 0.6100 - accuracy: 0.6687 - precision: 0.6905 - auc: 0.7232 - recall: 0.6692 - true_negatives: 157.0000 - val_loss: 0.7540 - val_accuracy: 0.5071 - val_precision: 0.5183 - val_auc: 0.3766 - val_recall: 0.8919 - val_true_negatives: 8.0000
# Epoch 28/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6859 - accuracy: 0.6323 - precision: 0.6875 - auc: 0.6761 - recall: 0.5500 - true_negatives: 170.0000 - val_loss: 0.8861 - val_accuracy: 0.5308 - val_precision: 0.5286 - val_auc: 0.3586 - val_recall: 1.0000 - val_true_negatives: 1.0000
# Epoch 29/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.7669 - accuracy: 0.5939 - precision: 0.6050 - auc: 0.6286 - recall: 0.6538 - true_negatives: 124.0000 - val_loss: 0.7199 - val_accuracy: 0.4976 - val_precision: 0.5138 - val_auc: 0.3680 - val_recall: 0.8378 - val_true_negatives: 12.0000
# Epoch 30/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6173 - accuracy: 0.6566 - precision: 0.6372 - auc: 0.7253 - recall: 0.8038 - true_negatives: 116.0000 - val_loss: 0.8347 - val_accuracy: 0.5308 - val_precision: 0.5286 - val_auc: 0.3687 - val_recall: 1.0000 - val_true_negatives: 1.0000
# Epoch 31/50
# 16/16 [==============================] - 192s 12s/step - loss: 0.6241 - accuracy: 0.6788 - precision: 0.7045 - auc: 0.7298 - recall: 0.6692 - true_negatives: 162.0000 - val_loss: 0.8221 - val_accuracy: 0.5308 - val_precision: 0.5286 - val_auc: 0.3926 - val_recall: 1.0000 - val_true_negatives: 1.0000
# Epoch 32/50
# 16/16 [==============================] - 195s 12s/step - loss: 0.6072 - accuracy: 0.6525 - precision: 0.6606 - auc: 0.7282 - recall: 0.6962 - true_negatives: 142.0000 - val_loss: 0.7635 - val_accuracy: 0.5355 - val_precision: 0.5314 - val_auc: 0.3940 - val_recall: 0.9910 - val_true_negatives: 3.0000
# Epoch 33/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.6224 - accuracy: 0.6061 - precision: 0.6117 - auc: 0.6890 - recall: 0.6846 - true_negatives: 122.0000 - val_loss: 0.7261 - val_accuracy: 0.5355 - val_precision: 0.5317 - val_auc: 0.4350 - val_recall: 0.9820 - val_true_negatives: 4.0000
# Epoch 34/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.7252 - accuracy: 0.5939 - precision: 0.6148 - auc: 0.6406 - recall: 0.6077 - true_negatives: 136.0000 - val_loss: 0.7551 - val_accuracy: 0.5450 - val_precision: 0.5373 - val_auc: 0.4513 - val_recall: 0.9730 - val_true_negatives: 7.0000
# Epoch 35/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6269 - accuracy: 0.6384 - precision: 0.6231 - auc: 0.7031 - recall: 0.7885 - true_negatives: 111.0000 - val_loss: 0.7193 - val_accuracy: 0.5592 - val_precision: 0.5464 - val_auc: 0.4444 - val_recall: 0.9550 - val_true_negatives: 12.0000
# Epoch 36/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.6037 - accuracy: 0.6424 - precision: 0.6531 - auc: 0.7204 - recall: 0.6808 - true_negatives: 141.0000 - val_loss: 0.7477 - val_accuracy: 0.5308 - val_precision: 0.5291 - val_auc: 0.4122 - val_recall: 0.9820 - val_true_negatives: 3.0000
# Epoch 37/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6135 - accuracy: 0.7030 - precision: 0.7233 - auc: 0.7483 - recall: 0.7038 - true_negatives: 165.0000 - val_loss: 0.7406 - val_accuracy: 0.4787 - val_precision: 0.5028 - val_auc: 0.3969 - val_recall: 0.8018 - val_true_negatives: 12.0000
# Epoch 38/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.6305 - accuracy: 0.6788 - precision: 0.7095 - auc: 0.7255 - recall: 0.6577 - true_negatives: 165.0000 - val_loss: 0.8076 - val_accuracy: 0.5450 - val_precision: 0.5377 - val_auc: 0.4127 - val_recall: 0.9640 - val_true_negatives: 8.0000
# Epoch 39/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.5979 - accuracy: 0.6667 - precision: 0.6955 - auc: 0.7381 - recall: 0.6500 - true_negatives: 161.0000 - val_loss: 0.8191 - val_accuracy: 0.5355 - val_precision: 0.5317 - val_auc: 0.3985 - val_recall: 0.9820 - val_true_negatives: 4.0000
# Epoch 40/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6589 - accuracy: 0.6606 - precision: 0.6544 - auc: 0.7129 - recall: 0.7500 - true_negatives: 132.0000 - val_loss: 0.8115 - val_accuracy: 0.5118 - val_precision: 0.5208 - val_auc: 0.3912 - val_recall: 0.9009 - val_true_negatives: 8.0000
# Epoch 41/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.5949 - accuracy: 0.6828 - precision: 0.6914 - auc: 0.7422 - recall: 0.7154 - true_negatives: 152.0000 - val_loss: 0.7799 - val_accuracy: 0.4550 - val_precision: 0.4873 - val_auc: 0.3838 - val_recall: 0.6937 - val_true_negatives: 19.0000
# Epoch 42/50
# 16/16 [==============================] - 177s 11s/step - loss: 0.6068 - accuracy: 0.6545 - precision: 0.6878 - auc: 0.7259 - recall: 0.6269 - true_negatives: 161.0000 - val_loss: 0.8091 - val_accuracy: 0.5308 - val_precision: 0.5291 - val_auc: 0.4035 - val_recall: 0.9820 - val_true_negatives: 3.0000
# Epoch 43/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6343 - accuracy: 0.6869 - precision: 0.6855 - auc: 0.7441 - recall: 0.7462 - true_negatives: 146.0000 - val_loss: 0.7813 - val_accuracy: 0.5829 - val_precision: 0.5608 - val_auc: 0.5150 - val_recall: 0.9550 - val_true_negatives: 17.0000
# Epoch 44/50
# 16/16 [==============================] - 175s 11s/step - loss: 0.6307 - accuracy: 0.6545 - precision: 0.6667 - auc: 0.7332 - recall: 0.6846 - true_negatives: 146.0000 - val_loss: 0.8870 - val_accuracy: 0.5355 - val_precision: 0.5314 - val_auc: 0.4188 - val_recall: 0.9910 - val_true_negatives: 3.0000
# Epoch 45/50
# 16/16 [==============================] - 178s 11s/step - loss: 0.5951 - accuracy: 0.6545 - precision: 0.6759 - auc: 0.7413 - recall: 0.6577 - true_negatives: 153.0000 - val_loss: 0.7971 - val_accuracy: 0.5545 - val_precision: 0.5423 - val_auc: 0.4395 - val_recall: 0.9820 - val_true_negatives: 8.0000
# Epoch 46/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.6016 - accuracy: 0.6404 - precision: 0.6667 - auc: 0.7248 - recall: 0.6308 - true_negatives: 153.0000 - val_loss: 0.7791 - val_accuracy: 0.4882 - val_precision: 0.5081 - val_auc: 0.4171 - val_recall: 0.8468 - val_true_negatives: 9.0000
# Epoch 47/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.5944 - accuracy: 0.6505 - precision: 0.6986 - auc: 0.7408 - recall: 0.5885 - true_negatives: 169.0000 - val_loss: 0.8641 - val_accuracy: 0.4787 - val_precision: 0.5028 - val_auc: 0.4413 - val_recall: 0.8108 - val_true_negatives: 11.0000
# Epoch 48/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.5707 - accuracy: 0.6505 - precision: 0.6347 - auc: 0.7513 - recall: 0.7885 - true_negatives: 117.0000 - val_loss: 0.8125 - val_accuracy: 0.5308 - val_precision: 0.5294 - val_auc: 0.4335 - val_recall: 0.9730 - val_true_negatives: 4.0000
# Epoch 49/50
# 16/16 [==============================] - 171s 11s/step - loss: 0.6242 - accuracy: 0.6505 - precision: 0.6761 - auc: 0.7254 - recall: 0.6423 - true_negatives: 155.0000 - val_loss: 0.7237 - val_accuracy: 0.5403 - val_precision: 0.5347 - val_auc: 0.6852 - val_recall: 0.9730 - val_true_negatives: 6.0000
# Epoch 50/50
# 16/16 [==============================] - 172s 11s/step - loss: 0.5766 - accuracy: 0.6949 - precision: 0.7026 - auc: 0.7761 - recall: 0.7269 - true_negatives: 155.0000 - val_loss: 0.8093 - val_accuracy: 0.5877 - val_precision: 0.5882 - val_auc: 0.5637 - val_recall: 0.7207 - val_true_negatives: 44.0000

# %%
import statistics
print (statistics.mean(history.history['accuracy']))
print (statistics.mean(history.history['val_accuracy']))
# Out:
# 0.6153131330013275
# 0.5060663533210754

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 15s 2s/step - loss: 0.8093 - accuracy: 0.5877 - precision: 0.5882 - auc: 0.5637 - recall: 0.7207 - true_negatives: 44.0000
# [0.8093134164810181,
#  0.5876777172088623,
#  0.5882353186607361,
#  0.5636937022209167,
#  0.7207207083702087,
#  44.0]
