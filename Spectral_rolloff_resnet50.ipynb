# %% [markdown]
# # Spectral_rolloff_resnet50

# %%
import cv2
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import keras
from keras.models import Sequential, Model,load_model
from keras import optimizers, losses, activations, models
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image
from keras.initializers import glorot_uniform
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

# %%
train_path= 'C:/Users/ASUS/Desktop/ResRollf/train'
test_path= 'C:/Users/ASUS/Desktop/ResRollf/test'
class_names=os.listdir(train_path)
class_names_test=os.listdir(test_path)

# %%
print(class_names)
print(class_names_test)
# Out:
# ['abnormal', 'normal']
# ['abnormal', 'normal']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15)
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow_from_directory('C:/Users/ASUS/Desktop/ResRollf/train',target_size=(224, 224),batch_size=32,shuffle=True,class_mode='binary')
test_generator = test_datagen.flow_from_directory('C:/Users/ASUS/Desktop/ResRollf/test',target_size=(224,224),batch_size=32,shuffle=False,class_mode='binary')
# Out:
# Found 495 images belonging to 2 classes.
# Found 211 images belonging to 2 classes.

# %%
def identity_block(X, f, filters, stage, block):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):
   
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')


    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)
    
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
base_model = ResNet50(input_shape=(224, 224, 3))

# %%
headModel = base_model.output
headModel = Flatten()(headModel)
headModel=Dense(256, activation='relu', name='fc1',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel=Dense(128, activation='relu', name='fc2',kernel_initializer=glorot_uniform(seed=0))(headModel)
headModel = Dense( 1,activation='sigmoid', name='fc3',kernel_initializer=glorot_uniform(seed=0))(headModel)

# %%
model = Model(inputs=base_model.input, outputs=headModel)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 55, 55, 64)   0           ['activation[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  fc1 (Dense)                    (None, 256)          8388864     ['flatten[0][0]']
#
#  fc2 (Dense)                    (None, 128)          32896       ['fc1[0][0]']
#
#  fc3 (Dense)                    (None, 1)            129         ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 32,009,601
# Trainable params: 31,956,481
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# weight_path="{}_weights.best.hdf5".format('spectro_sound_model')
checkpoint = ModelCheckpoint(filepath ="./check.hDf5", monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)
# reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', 
#                                    factor=0.8, patience=5, 
#                                    verbose=1, mode='auto', 
#                                    epsilon=0.0001, cooldown=5, 
#                                    min_lr=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early]

# %%
import tensorflow as tf
from keras.models import *
from keras.layers import *
opt = tf.optimizers.Adam(lr=1e-3)
model.compile(optimizer=opt, 
    loss=losses.binary_crossentropy, 
    metrics=['accuracy', 'Precision', 'AUC', tf.keras.metrics.Recall(), tf.keras.metrics.TrueNegatives()])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
training_images = 456
validation_images = 144 

history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results. 
                   epochs = 50,  # change this for better results
                   validation_data = test_generator)  # this should be equal to total number of images in validation set.
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_11284/615836474.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator, # this should be equal to total number of images in training set. But to speed up the execution, I am only using 10000 images. Change this for better results.
# Epoch 1/50
# 16/16 [==============================] - 188s 11s/step - loss: 6.2528 - accuracy: 0.4828 - precision: 0.5080 - auc: 0.4576 - recall: 0.4885 - true_negatives: 112.0000 - val_loss: 289356.5938 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 2/50
# 16/16 [==============================] - 178s 11s/step - loss: 1.3578 - accuracy: 0.5495 - precision: 0.5725 - auc: 0.5494 - recall: 0.5615 - true_negatives: 126.0000 - val_loss: 45.9006 - val_accuracy: 0.4739 - val_precision: 0.0000e+00 - val_auc: 0.5000 - val_recall: 0.0000e+00 - val_true_negatives: 100.0000
# Epoch 3/50
# 16/16 [==============================] - 198s 12s/step - loss: 1.3066 - accuracy: 0.5212 - precision: 0.5409 - auc: 0.5549 - recall: 0.5846 - true_negatives: 106.0000 - val_loss: 12641.0283 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5000 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 4/50
# 16/16 [==============================] - 207s 13s/step - loss: 1.2451 - accuracy: 0.5051 - precision: 0.5325 - auc: 0.5425 - recall: 0.4731 - true_negatives: 127.0000 - val_loss: 57.0184 - val_accuracy: 0.5213 - val_precision: 0.5240 - val_auc: 0.4977 - val_recall: 0.9820 - val_true_negatives: 1.0000
# Epoch 5/50
# 16/16 [==============================] - 226s 14s/step - loss: 0.9969 - accuracy: 0.5091 - precision: 0.5282 - auc: 0.5223 - recall: 0.6115 - true_negatives: 93.0000 - val_loss: 0.8059 - val_accuracy: 0.4171 - val_precision: 0.0714 - val_auc: 0.3858 - val_recall: 0.0090 - val_true_negatives: 87.0000
# Epoch 6/50
# 16/16 [==============================] - 183s 11s/step - loss: 0.7377 - accuracy: 0.5899 - precision: 0.7280 - auc: 0.6045 - recall: 0.3500 - true_negatives: 201.0000 - val_loss: 0.6979 - val_accuracy: 0.4976 - val_precision: 0.5123 - val_auc: 0.4623 - val_recall: 0.9369 - val_true_negatives: 1.0000
# Epoch 7/50
# 16/16 [==============================] - 177s 11s/step - loss: 0.7796 - accuracy: 0.5980 - precision: 0.6041 - auc: 0.6554 - recall: 0.6808 - true_negatives: 119.0000 - val_loss: 0.7012 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.5571 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 8/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.9828 - accuracy: 0.5051 - precision: 0.5292 - auc: 0.5366 - recall: 0.5231 - true_negatives: 114.0000 - val_loss: 0.7225 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4958 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 9/50
# 16/16 [==============================] - 179s 11s/step - loss: 0.7836 - accuracy: 0.5697 - precision: 0.6114 - auc: 0.6135 - recall: 0.4962 - true_negatives: 153.0000 - val_loss: 0.7960 - val_accuracy: 0.5261 - val_precision: 0.5261 - val_auc: 0.4350 - val_recall: 1.0000 - val_true_negatives: 0.0000e+00
# Epoch 10/50
# 16/16 [==============================] - 180s 11s/step - loss: 0.8415 - accuracy: 0.5636 - precision: 0.6158 - auc: 0.5914 - recall: 0.4500 - true_negatives: 162.0000 - val_loss: 0.7116 - val_accuracy: 0.4645 - val_precision: 0.3333 - val_auc: 0.4127 - val_recall: 0.0180 - val_true_negatives: 96.0000
# Epoch 11/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.6660 - accuracy: 0.5697 - precision: 0.5802 - auc: 0.6088 - recall: 0.6538 - true_negatives: 112.0000 - val_loss: 0.7167 - val_accuracy: 0.4597 - val_precision: 0.4884 - val_auc: 0.3774 - val_recall: 0.5676 - val_true_negatives: 34.0000
# Epoch 12/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.7318 - accuracy: 0.6061 - precision: 0.6879 - auc: 0.6767 - recall: 0.4577 - true_negatives: 181.0000 - val_loss: 0.7621 - val_accuracy: 0.5308 - val_precision: 0.5286 - val_auc: 0.3803 - val_recall: 1.0000 - val_true_negatives: 1.0000
# Epoch 13/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.6468 - accuracy: 0.6606 - precision: 0.6742 - auc: 0.7200 - recall: 0.6846 - true_negatives: 149.0000 - val_loss: 0.7350 - val_accuracy: 0.4265 - val_precision: 0.4691 - val_auc: 0.4278 - val_recall: 0.6847 - val_true_negatives: 14.0000
# Epoch 14/50
# 16/16 [==============================] - 177s 11s/step - loss: 0.7050 - accuracy: 0.6303 - precision: 0.6711 - auc: 0.6701 - recall: 0.5808 - true_negatives: 161.0000 - val_loss: 0.7271 - val_accuracy: 0.4408 - val_precision: 0.4762 - val_auc: 0.4768 - val_recall: 0.6306 - val_true_negatives: 23.0000
# Epoch 15/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.6123 - accuracy: 0.6263 - precision: 0.6728 - auc: 0.6980 - recall: 0.5615 - true_negatives: 164.0000 - val_loss: 0.7494 - val_accuracy: 0.4408 - val_precision: 0.4755 - val_auc: 0.4683 - val_recall: 0.6126 - val_true_negatives: 25.0000
# Epoch 16/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6445 - accuracy: 0.6202 - precision: 0.6304 - auc: 0.6807 - recall: 0.6692 - true_negatives: 133.0000 - val_loss: 0.7392 - val_accuracy: 0.4076 - val_precision: 0.3906 - val_auc: 0.3953 - val_recall: 0.2252 - val_true_negatives: 61.0000
# Epoch 17/50
# 16/16 [==============================] - 173s 11s/step - loss: 0.6482 - accuracy: 0.6566 - precision: 0.7163 - auc: 0.7101 - recall: 0.5731 - true_negatives: 176.0000 - val_loss: 0.7669 - val_accuracy: 0.4502 - val_precision: 0.4667 - val_auc: 0.4136 - val_recall: 0.3153 - val_true_negatives: 60.0000
# Epoch 18/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.6198 - accuracy: 0.6283 - precision: 0.6234 - auc: 0.7124 - recall: 0.7385 - true_negatives: 119.0000 - val_loss: 0.8121 - val_accuracy: 0.4360 - val_precision: 0.4767 - val_auc: 0.4055 - val_recall: 0.7387 - val_true_negatives: 10.0000
# Epoch 19/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.6626 - accuracy: 0.6444 - precision: 0.6544 - auc: 0.7024 - recall: 0.6846 - true_negatives: 141.0000 - val_loss: 0.7382 - val_accuracy: 0.4550 - val_precision: 0.4884 - val_auc: 0.3767 - val_recall: 0.7568 - val_true_negatives: 12.0000
# Epoch 20/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.6530 - accuracy: 0.6667 - precision: 0.7039 - auc: 0.7138 - recall: 0.6308 - true_negatives: 166.0000 - val_loss: 0.7503 - val_accuracy: 0.4550 - val_precision: 0.4873 - val_auc: 0.3861 - val_recall: 0.6937 - val_true_negatives: 19.0000
# Epoch 21/50
# 16/16 [==============================] - 189s 12s/step - loss: 0.6140 - accuracy: 0.6848 - precision: 0.6955 - auc: 0.7464 - recall: 0.7115 - true_negatives: 154.0000 - val_loss: 0.7770 - val_accuracy: 0.4645 - val_precision: 0.4924 - val_auc: 0.3819 - val_recall: 0.5856 - val_true_negatives: 33.0000
# Epoch 22/50
# 16/16 [==============================] - 189s 12s/step - loss: 0.6286 - accuracy: 0.6586 - precision: 0.6704 - auc: 0.7193 - recall: 0.6885 - true_negatives: 147.0000 - val_loss: 0.8132 - val_accuracy: 0.4597 - val_precision: 0.4914 - val_auc: 0.3985 - val_recall: 0.7748 - val_true_negatives: 11.0000
# Epoch 23/50
# 16/16 [==============================] - 183s 11s/step - loss: 0.6229 - accuracy: 0.6566 - precision: 0.6490 - auc: 0.7097 - recall: 0.7538 - true_negatives: 129.0000 - val_loss: 0.8367 - val_accuracy: 0.4597 - val_precision: 0.4904 - val_auc: 0.4022 - val_recall: 0.6937 - val_true_negatives: 20.0000
# Epoch 24/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6038 - accuracy: 0.6525 - precision: 0.6366 - auc: 0.7175 - recall: 0.7885 - true_negatives: 118.0000 - val_loss: 0.8955 - val_accuracy: 0.4976 - val_precision: 0.5132 - val_auc: 0.3467 - val_recall: 0.8739 - val_true_negatives: 8.0000
# Epoch 25/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6330 - accuracy: 0.6808 - precision: 0.6889 - auc: 0.7412 - recall: 0.7154 - true_negatives: 151.0000 - val_loss: 0.8348 - val_accuracy: 0.4455 - val_precision: 0.4803 - val_auc: 0.3715 - val_recall: 0.6577 - val_true_negatives: 21.0000
# Epoch 26/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.6634 - accuracy: 0.6101 - precision: 0.6264 - auc: 0.6593 - recall: 0.6385 - true_negatives: 136.0000 - val_loss: 0.7516 - val_accuracy: 0.4455 - val_precision: 0.4821 - val_auc: 0.3887 - val_recall: 0.7297 - val_true_negatives: 13.0000
# Epoch 27/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6377 - accuracy: 0.6808 - precision: 0.7257 - auc: 0.7166 - recall: 0.6308 - true_negatives: 173.0000 - val_loss: 0.6884 - val_accuracy: 0.5924 - val_precision: 0.5954 - val_auc: 0.5873 - val_recall: 0.7027 - val_true_negatives: 47.0000
# Epoch 28/50
# 16/16 [==============================] - 184s 11s/step - loss: 0.6463 - accuracy: 0.6222 - precision: 0.6388 - auc: 0.7031 - recall: 0.6462 - true_negatives: 140.0000 - val_loss: 0.7929 - val_accuracy: 0.5355 - val_precision: 0.5340 - val_auc: 0.5236 - val_recall: 0.9189 - val_true_negatives: 11.0000
# Epoch 29/50
# 16/16 [==============================] - 189s 12s/step - loss: 0.5885 - accuracy: 0.6828 - precision: 0.6943 - auc: 0.7512 - recall: 0.7077 - true_negatives: 154.0000 - val_loss: 0.7472 - val_accuracy: 0.5355 - val_precision: 0.5330 - val_auc: 0.5518 - val_recall: 0.9459 - val_true_negatives: 8.0000
# Epoch 30/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.6606 - accuracy: 0.6222 - precision: 0.6197 - auc: 0.6884 - recall: 0.7269 - true_negatives: 119.0000 - val_loss: 0.7690 - val_accuracy: 0.4739 - val_precision: 0.5000 - val_auc: 0.5259 - val_recall: 0.6216 - val_true_negatives: 31.0000
# Epoch 31/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.6494 - accuracy: 0.6364 - precision: 0.6709 - auc: 0.6789 - recall: 0.6038 - true_negatives: 158.0000 - val_loss: 0.9060 - val_accuracy: 0.5308 - val_precision: 0.5306 - val_auc: 0.4350 - val_recall: 0.9369 - val_true_negatives: 8.0000
# Epoch 32/50
# 16/16 [==============================] - 187s 12s/step - loss: 0.6132 - accuracy: 0.6869 - precision: 0.6829 - auc: 0.7313 - recall: 0.7538 - true_negatives: 144.0000 - val_loss: 0.9484 - val_accuracy: 0.5403 - val_precision: 0.5343 - val_auc: 0.4243 - val_recall: 0.9820 - val_true_negatives: 5.0000
# Epoch 33/50
# 16/16 [==============================] - 184s 11s/step - loss: 0.5567 - accuracy: 0.7111 - precision: 0.7368 - auc: 0.7843 - recall: 0.7000 - true_negatives: 170.0000 - val_loss: 0.9631 - val_accuracy: 0.4976 - val_precision: 0.5137 - val_auc: 0.4467 - val_recall: 0.8468 - val_true_negatives: 11.0000
# Epoch 34/50
# 16/16 [==============================] - 188s 12s/step - loss: 0.5757 - accuracy: 0.7071 - precision: 0.6910 - auc: 0.7553 - recall: 0.8000 - true_negatives: 142.0000 - val_loss: 0.8967 - val_accuracy: 0.5450 - val_precision: 0.5369 - val_auc: 0.5830 - val_recall: 0.9820 - val_true_negatives: 6.0000
# Epoch 35/50
# 16/16 [==============================] - 196s 12s/step - loss: 0.5864 - accuracy: 0.6727 - precision: 0.6713 - auc: 0.7508 - recall: 0.7385 - true_negatives: 141.0000 - val_loss: 0.8257 - val_accuracy: 0.4787 - val_precision: 0.5029 - val_auc: 0.4481 - val_recall: 0.7748 - val_true_negatives: 15.0000
# Epoch 36/50
# 16/16 [==============================] - 194s 12s/step - loss: 0.5546 - accuracy: 0.7152 - precision: 0.7102 - auc: 0.7878 - recall: 0.7731 - true_negatives: 153.0000 - val_loss: 0.8858 - val_accuracy: 0.4597 - val_precision: 0.4907 - val_auc: 0.3942 - val_recall: 0.7117 - val_true_negatives: 18.0000
# Epoch 37/50
# 16/16 [==============================] - 195s 12s/step - loss: 0.5563 - accuracy: 0.6747 - precision: 0.6827 - auc: 0.7735 - recall: 0.7115 - true_negatives: 149.0000 - val_loss: 0.8567 - val_accuracy: 0.5355 - val_precision: 0.5340 - val_auc: 0.4857 - val_recall: 0.9189 - val_true_negatives: 11.0000
# Epoch 38/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.5505 - accuracy: 0.7071 - precision: 0.6837 - auc: 0.7771 - recall: 0.8231 - true_negatives: 136.0000 - val_loss: 0.9258 - val_accuracy: 0.4976 - val_precision: 0.5137 - val_auc: 0.4667 - val_recall: 0.8468 - val_true_negatives: 11.0000
# Epoch 39/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.5373 - accuracy: 0.7192 - precision: 0.7373 - auc: 0.8032 - recall: 0.7231 - true_negatives: 168.0000 - val_loss: 1.1201 - val_accuracy: 0.4645 - val_precision: 0.4938 - val_auc: 0.4335 - val_recall: 0.7207 - val_true_negatives: 18.0000
# Epoch 40/50
# 16/16 [==============================] - 193s 12s/step - loss: 0.5445 - accuracy: 0.7111 - precision: 0.6997 - auc: 0.7832 - recall: 0.7885 - true_negatives: 147.0000 - val_loss: 1.0445 - val_accuracy: 0.5308 - val_precision: 0.5319 - val_auc: 0.4518 - val_recall: 0.9009 - val_true_negatives: 12.0000
# Epoch 41/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.5498 - accuracy: 0.7293 - precision: 0.7172 - auc: 0.7948 - recall: 0.8000 - true_negatives: 153.0000 - val_loss: 0.9602 - val_accuracy: 0.4882 - val_precision: 0.5087 - val_auc: 0.4109 - val_recall: 0.7928 - val_true_negatives: 15.0000
# Epoch 42/50
# 16/16 [==============================] - 192s 12s/step - loss: 0.5593 - accuracy: 0.6970 - precision: 0.6937 - auc: 0.7810 - recall: 0.7577 - true_negatives: 148.0000 - val_loss: 0.8339 - val_accuracy: 0.5355 - val_precision: 0.5359 - val_auc: 0.4210 - val_recall: 0.8739 - val_true_negatives: 16.0000
# Epoch 43/50
# 16/16 [==============================] - 186s 12s/step - loss: 0.5455 - accuracy: 0.7232 - precision: 0.6977 - auc: 0.7821 - recall: 0.8346 - true_negatives: 141.0000 - val_loss: 0.8666 - val_accuracy: 0.4645 - val_precision: 0.4940 - val_auc: 0.3903 - val_recall: 0.7477 - val_true_negatives: 15.0000
# Epoch 44/50
# 16/16 [==============================] - 197s 12s/step - loss: 0.5167 - accuracy: 0.7414 - precision: 0.7230 - auc: 0.7997 - recall: 0.8231 - true_negatives: 153.0000 - val_loss: 1.0886 - val_accuracy: 0.4834 - val_precision: 0.5059 - val_auc: 0.4273 - val_recall: 0.7748 - val_true_negatives: 16.0000
# Epoch 45/50
# 16/16 [==============================] - 176s 11s/step - loss: 0.5399 - accuracy: 0.7374 - precision: 0.7138 - auc: 0.8111 - recall: 0.8346 - true_negatives: 148.0000 - val_loss: 0.8569 - val_accuracy: 0.5071 - val_precision: 0.5189 - val_auc: 0.4835 - val_recall: 0.8649 - val_true_negatives: 11.0000
# Epoch 46/50
# 16/16 [==============================] - 174s 11s/step - loss: 0.5363 - accuracy: 0.7333 - precision: 0.7406 - auc: 0.8107 - recall: 0.7577 - true_negatives: 166.0000 - val_loss: 1.0316 - val_accuracy: 0.5403 - val_precision: 0.5361 - val_auc: 0.4009 - val_recall: 0.9369 - val_true_negatives: 10.0000
# Epoch 47/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.5275 - accuracy: 0.7414 - precision: 0.7200 - auc: 0.8056 - recall: 0.8308 - true_negatives: 151.0000 - val_loss: 0.9677 - val_accuracy: 0.5166 - val_precision: 0.5231 - val_auc: 0.4201 - val_recall: 0.9189 - val_true_negatives: 7.0000
# Epoch 48/50
# 16/16 [==============================] - 179s 11s/step - loss: 0.5182 - accuracy: 0.7576 - precision: 0.7612 - auc: 0.8159 - recall: 0.7846 - true_negatives: 171.0000 - val_loss: 0.9265 - val_accuracy: 0.4882 - val_precision: 0.5080 - val_auc: 0.4630 - val_recall: 0.8559 - val_true_negatives: 8.0000
# Epoch 49/50
# 16/16 [==============================] - 185s 12s/step - loss: 0.5077 - accuracy: 0.7495 - precision: 0.7267 - auc: 0.8283 - recall: 0.8385 - true_negatives: 153.0000 - val_loss: 1.0795 - val_accuracy: 0.4739 - val_precision: 0.5000 - val_auc: 0.3883 - val_recall: 0.7748 - val_true_negatives: 14.0000
# Epoch 50/50
# 16/16 [==============================] - 191s 12s/step - loss: 0.4795 - accuracy: 0.7859 - precision: 0.7619 - auc: 0.8434 - recall: 0.8615 - true_negatives: 165.0000 - val_loss: 0.9621 - val_accuracy: 0.4787 - val_precision: 0.5031 - val_auc: 0.4680 - val_recall: 0.7387 - val_true_negatives: 19.0000

# %%
import statistics
print (statistics.mean(history.history['accuracy']))
print (statistics.mean(history.history['val_accuracy']))
# Out:
# 0.6518383818864822
# 0.48843601942062376

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 7/7 [==============================] - 15s 2s/step - loss: 0.9621 - accuracy: 0.4787 - precision: 0.5031 - auc: 0.4680 - recall: 0.7387 - true_negatives: 19.0000
# [0.9621059894561768,
#  0.47867298126220703,
#  0.5030674934387207,
#  0.4680179953575134,
#  0.7387387156486511,
#  19.0]
